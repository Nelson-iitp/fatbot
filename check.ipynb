# %% [markdown]
# # []

# %%
import numpy as np
from scipy.spatial import ConvexHull, convex_hull_plot_2d
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng()

# %%
points = rng.random((8, 2))   # 30 random points in 2-D
plt.scatter(points[:,0], points[:,1])

# %%
hull = ConvexHull(points)
hull

# %%
plt.scatter(points[:,0], points[:,1])
#plt.scatter(hull.simplices[:,0], hull.simplices[:,1])
for simplex in hull.simplices:
    print(f'{simplex=}, {points[simplex, 0]}, {points[simplex, 1]}')
    plt.plot(points[simplex, 0], points[simplex, 1], 'k-')
# Out:
# simplex=array([1, 5], dtype=int32), [0.94886957 0.0817069 ], [0.30793824 0.863374  ]
# simplex=array([6, 7], dtype=int32), [0.3128194  0.44500858], [0.24065988 0.07403779]
# simplex=array([3, 1], dtype=int32), [0.52656418 0.94886957], [0.08620899 0.30793824]
# simplex=array([3, 7], dtype=int32), [0.52656418 0.44500858], [0.08620899 0.07403779]
# simplex=array([2, 5], dtype=int32), [0.11740023 0.0817069 ], [0.71198553 0.863374  ]
# simplex=array([2, 6], dtype=int32), [0.11740023 0.3128194 ], [0.71198553 0.24065988]

# %%
plt.plot(points[hull.vertices,0], points[hull.vertices,1], 'r--', lw=2)

# %%
x, y = points[hull.vertices, 0], points[hull.vertices, 1]
x, y
# Out:
# (array([0.94886957, 0.0817069 , 0.11740023, 0.3128194 , 0.44500858,
#         0.52656418]),
#  array([0.30793824, 0.863374  , 0.71198553, 0.24065988, 0.07403779,
#         0.08620899]))

# %%
int(False)
# Out:
# 0

# %%
hull.vertices
# Out:
# array([1, 5, 2, 6, 7, 3], dtype=int32)

# %%
plt.plot(points[hull.vertices,0], points[hull.vertices,1], 'r--', lw=2)
plt.plot(points[hull.vertices[0],0], points[hull.vertices[0],1], 'ro')
plt.show()
